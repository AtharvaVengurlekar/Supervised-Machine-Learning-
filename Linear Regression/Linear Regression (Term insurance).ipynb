# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv(r'C:\Users\Atharva Vengurlekar\Desktop\Machine Learning\Term Insurance dataset.csv')
print(df)
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
#Find the premium whose age is 21 and 50

# %%
sns.lmplot(x='Age',y='Premium', data = df)
# Out:
# C:\Users\Atharva Vengurlekar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['Age']],df['Premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Users\Atharva Vengurlekar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13880.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\Atharva Vengurlekar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65500.])
